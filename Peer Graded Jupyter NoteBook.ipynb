# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Mihreteab Tesfamariam**
#
# Data Science or Data Analytics

# %% [markdown]
# *I am interested in data science because, I am a detective person; I love to solve puzzle, which is very dependent in Data. Besides, I have studied statistics and have an experience in data analysis.*

# %% [markdown]
# ### My code is intended to perform simple math operations

# %%
2 + 7 - 3
# Out:
# 6

# %% [markdown]
# This Jupyter Note Book code is intended to perform the following simple tasks.
# * Create a notebook with different styles
# * Descriptive inormation
# * code to perform simple math
# * Horizontal rule
# * List and
# * Table
#
# ***
#
#
# A Mathematical Operation Table:
#
#
# FirstNumber | SecondNumber | Task | Value
# --- | --- | --- | ---
# 10 | 3 | * | 30
# 1 | 8 | + | 9
# 5 | 0 | - | 5
